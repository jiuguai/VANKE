# %%
import tools as gdt

from config import *

import shutil

token = "eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiIwNzMxYmM2ZDgzMDE0MDQ5OTNhMDA4ZWRhZjZkZDJjYyIsImF1ZGllbmNlIjoid2ViIiwiY3JlYXRlZCI6MTU1NzQ2MDQ3MTM3MiwiZXhwIjoxNTU4MDY1MjcxfQ.54N_Wo2kyriuGzOJNK2L3PO9sBvRxr3JTdQKyTngWugfFywfEN7knSRWOc5HMoRnk6MTT03QAW1gdp9alXJNOw"





# 认购签约
area = "orderSvc" 
# 已签约
# area= "contractSvc"

# %%
gdt.get_stageid_df(token)
# Out:
#                      分期名称                                  分期ID
# 0                长沙万科城-一期  DE68BE70-EF64-46A6-8D82-5EB3918F7931
# 1           长沙万科城-三期(调整1)      fabcc50a09f6604c430b4090bc7affda
# 2           长沙万科城-三期(调整2)      78f7478593ec494773987ba928658419
# 3                长沙万科城-二期  2C2E1E33-6DD3-4EA0-9AA6-71EA66D046F8
# 4             长沙万科金域滨江-一期  16743C51-6D54-4319-A025-71B2F0852823
# 5           长沙万科金域滨江-一期车位  94FA7B82-4759-4DF0-9F93-E0D355D06F68
# 6      长沙万科金域滨江-长沙金域滨江第二期  012C7D06-AA4A-424A-B354-EDD3B46880D6
# 7             长沙万科金域缇香-一期  F8ED1858-2958-455F-A804-15837AA570A7
# 8              长沙东方红项目一分期      b83aa8cd02dc4c8cabe3f3c68a6ed2aa
# 9       长沙四季花城二-长沙四季花城第三期  8D82E4C9-8442-4EA0-BB5B-47016A3235AE
# 10      长沙四季花城二-长沙四季花城第四期  D42A0783-31C4-46DF-8B0B-71AAE729F2BD
# 11              长沙城市花园-一期  24D15949-14DB-4741-9FC8-C2BA53577EE5
# 12              长沙城市花园-二期  EB62ADDB-6A92-45A1-B797-D6E778B016BD
# 13              长沙城际新苑-一期  106A63E7-BACB-4DB0-8583-2ADD2E224C75
# ...

# %%
# import pandas as pd

# writer = pd.ExcelWriter(r"C:\Users\vkad\Desktop\test.xlsx")
# df_t.to_excel(writer)
# writer.save()

# %%
stage_id = "6981c248-8da2-4f7f-a03b-e7e02d1c0060"

tradeid_set = gdt.get_order_svc_set(stage_id,token)

# %%
len(tradeid_set)
# Out:
# 277

# %%
data = gdt.get_data(tradeid_set,token)
indexlp_l = ['长沙白鹭郡','长沙金域国际','长沙梅溪郡', '长沙金域滨江',  '长沙金域缇香',  '长沙紫台',"长沙东方红项目"]

indexmx_l = ['白鹭郡','百汇','梅溪郡','滨江',  '缇香','紫台',"金色梦想"]

xm_lp_map_mx = dict(zip(indexlp_l,indexmx_l))
data = gdt.dec_data(data,xm_lp_map_mx)
# Out:
# 8.78860092163086s

# %%
save_path = r"C:\Users\vkad\Desktop\result\data_map\金色梦想_data.xlsx"
gdt.save_data_map(data,save_path)

# %%
stop

# %%
gd_b = r"\\Mjbc04-csdcc\金梦b"
gd_c = r"\\Sj-1\金梦c"
# shutil.copyfile(save_path,gd_b + r"\金色梦想_data.xlsx")
shutil.copyfile(save_path,gd_c + r"\金色梦想_data.xlsx")
# Out:
# '\\\\Sj-1\\金梦c\\金色梦想_data.xlsx'

# %%
data
